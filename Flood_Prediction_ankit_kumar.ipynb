# %% [markdown]
# # 1. Introduction (Flood Prediction)
# My name is [Mr. Ankit Kumar], and I am currently a student of [B-Tech/CSE/3rd].
# I have chosen to work on the Flood Prediction
# Project because I am interested in the application of machine learning and data science to solve real-life problems.
#
# Flooding is one of the most frequent and devastating natural disasters worldwide,
# causing significant damage to human lives, infrastructure, agriculture, and the environment.
# Predicting floods in advance is essential to reduce their impact through timely warning systems,
# disaster preparedness, and effective resource allocation.
#
# With the advancement of data science and machine learning, flood prediction can be made more accurate by
# analyzing historical data such as rainfall, river water levels, temperature, humidity, soil saturation, and
# other environmental indicators. By training models on these datasets, we can identify patterns that signal
# the likelihood of flooding in a particular region.

# %% [markdown]
# # 2. Import Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# # 3. Load Dataset

# %%
# Membaca dataset
data = pd.read_csv("flood.csv")
print(f'flood.csv : {data.shape}')
data.head(3)
# Out:
# flood.csv : (50000, 21)
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
#
#    Encroachments  ...  DrainageSystems  CoastalVulnerability  Landslides  \
# 0              2  ...               10                     7           4
# 1              4  ...                9                     2           6
# 2              9  ...                7                     4           4
#
# ...

# %% [markdown]
# # 4. Pre Processing

# %%
X = data.drop(labels=['FloodProbability'], axis=1)
Y = data['FloodProbability']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %% [markdown]
# # 5. EDA
# Mengidentifikasi jenis data, ukuran dataset, dan distribusi variabel untuk mengetahui karakteristiknya.

# %%
print("Lima baris pertama dataset:")
print(data.head())
print("\nStatistik deskriptif:\n", data.describe())
# Out:
# Lima baris pertama dataset:
#    MonsoonIntensity  TopographyDrainage  RiverManagement  Deforestation  \
# 0                 3                   8                6              6
# 1                 8                   4                5              7
# 2                 3                  10                4              1
# 3                 4                   4                2              7
# 4                 3                   7                5              2
#
#    Urbanization  ClimateChange  DamsQuality  Siltation  AgriculturalPractices  \
# 0             4              4            6          2                      3
# 1             7              9            1          5                      5
# 2             7              5            4          7                      4
# 3             3              4            1          4                      6
# 4             5              8            5          2                      7
#
# ...

# %% [markdown]
# KORELASI DENGAN HEATMAP

# %%
corr = data.corr()
fig, ax = plt.subplots(figsize=(15, 10))
sns.heatmap(corr, annot=True, linewidths=.5, ax=ax)
plt.title("Heatmap Korelasi Fitur")
plt.show()

# %% [markdown]
# # 6.MODELLING DENGAN RANDOM FOREST DAN SVM

# %% [markdown]
# RANDOM FOREST

# %%
# Model Random Forest
model_rf = RandomForestRegressor()
model_rf.fit(X_train, Y_train)
y_pred_rf = model_rf.predict(X_test)

# %%
# Evaluasi Random Forest
print("\nEvaluasi Model Random Forest:")
print('Accuracy: ', model_rf.score(X_test, Y_test))
r2_rf = r2_score(Y_test, y_pred_rf)
mae_rf = mean_absolute_error(Y_test, y_pred_rf)
mse_rf = mean_squared_error(Y_test, y_pred_rf)
print("MSE:", mse_rf)
print("MAE:", mae_rf)
print("R2 SCORE:", r2_rf)
# Out:
# Evaluasi Model Random Forest:
# Accuracy:  0.7280380640579178
# MSE: 0.0006773445205000005
# MAE: 0.02050739000000001
# R2 SCORE: 0.7280380640579178

# %% [markdown]
# SVM

# %%
model_svm = SVR(kernel='rbf')
model_svm.fit(X_train, Y_train)
y_pred_svm = model_svm.predict(X_test)

# %%
# Evaluasi SVM
print("\nEvaluasi Model SVM:")
print('Accuracy: ', model_svm.score(X_test, Y_test))
r2_svm = r2_score(Y_test, y_pred_svm)
mae_svm = mean_absolute_error(Y_test, y_pred_svm)
mse_svm = mean_squared_error(Y_test, y_pred_svm)
print("MSE:", mse_svm)
print("MAE:", mae_svm)
print("R2 SCORE:", r2_svm)
# Out:
# Evaluasi Model SVM:
# Accuracy:  0.7200938781158139
# MSE: 0.0006971301967531037
# MAE: 0.020156666792254037
# R2 SCORE: 0.7200938781158139

# %% [markdown]
# # conclusion
#
# Floods remain one of the most dangerous natural disasters, and accurate prediction is crucial to minimize their impact on human life, property, and the environment. In this project, we applied machine learning techniques to predict the likelihood of flooding based on environmental and meteorological data.
#
# The results demonstrate that predictive models can be a valuable tool for early warning systems, supporting disaster preparedness and decision-making. While the model provides useful insights, its accuracy and reliability depend on the quality and quantity of the data used.
#
# Future improvements can include:
#
# . Using larger and real-time datasets from weather stations and satellite data.
#
# . Combining multiple algorithms to improve prediction accuracy.
#
# . Developing a user-friendly dashboard or mobile app for public awareness.
#
# . Overall, this project highlights the potential of data science and artificial intelligence in addressing real-world challenges and contributing to disaster risk reduction.
